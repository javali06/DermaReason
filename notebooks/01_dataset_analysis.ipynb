# %%
import os

print(os.path.exists(r"C:\Projects\DermaReason\dataset\metadata"))

df.to_csv(
    r"C:\Projects\DermaReason\dataset\metadata\processed_metadata.csv",
    index=False
)

print("Saved successfully")
# Out:
# True
# Saved successfully

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["label"],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    stratify=temp_df["label"],
    random_state=42
)

# %%
print(len(train_df))
print(len(val_df))
print(len(test_df))
# Out:
# 7010
# 1502
# 1503

# %%
train_df.to_csv(
    r"C:\Projects\DermaReason\dataset\metadata\train.csv",
    index=False
)

val_df.to_csv(
    r"C:\Projects\DermaReason\dataset\metadata\val.csv",
    index=False
)

test_df.to_csv(
    r"C:\Projects\DermaReason\dataset\metadata\test.csv",
    index=False
)

# %%
print(df["label"].value_counts())
print(len(train_df), len(val_df), len(test_df))
# Out:
# label
# 5    6705
# 4    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: count, dtype: int64
# 7010 1502 1503

# %%
import torch

print(torch.cuda.is_available())
# Out:
# False
